# %%
from PIL import Image
import imagehash
import os
import matplotlib.pyplot as plt
import numpy as np

data_dir = "data/NBDL"
files = sorted(os.listdir(data_dir), key=lambda x: int(x.split('_')[1].split('.')[0]))

# Tính tất cả Hamming distances giữa các cặp liền kề
hamming_distances = []
pairs = []
for i in range(len(files)-1):
    p1 = os.path.join(data_dir, files[i])
    p2 = os.path.join(data_dir, files[i+1])
    h1 = imagehash.phash(Image.open(p1))
    h2 = imagehash.phash(Image.open(p2))
    d = h1 - h2
    hamming_distances.append(d)
    pairs.append((files[i], files[i+1], d))

hamming_arr = np.array(hamming_distances)

# Vẽ histogram (quan sát phân phối)
plt.figure(figsize=(8,4))
plt.hist(hamming_arr, bins=range(0, max(hamming_arr)+2), edgecolor='k')
plt.xlabel('Hamming distance')
plt.ylabel('Count')
plt.title('Histogram Hamming distances giữa frame liền kề')
plt.show()

# So sánh với vài ngưỡng để biết số cặp "gần giống"
thresholds = [1,2,3,4,5,6,8,10]
for t in thresholds:
    c = np.sum(hamming_arr <= t)
    print(f"<= {t}: {c} cặp ({c/len(hamming_arr):.2%})")

# %% [markdown]
# # Loại bỏ ảnh mờ

# %%
import cv2
import numpy as np
import os
import fnmatch

# %%
PCT = 10  # loại ảnh dưới percentil PCT
PATTERN = "frame_*.jpg"
ROOT_DIR = "data"  # folder gốc chứa nhiều folder con

# %%
def var_laplacian_gray(img_path):
    """Trả về variance of Laplacian (float) hoặc None nếu không đọc được."""
    img = cv2.imread(img_path)
    if img is None:
        try:
            img = cv2.imdecode(np.fromfile(img_path, dtype=np.uint8), cv2.IMREAD_COLOR)
        except Exception:
            return None
        if img is None:
            return None
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    return float(cv2.Laplacian(gray, cv2.CV_64F).var())

# %%
# Lưu kết quả của từng folder
results = {}

# %%
for folder in os.listdir(ROOT_DIR):
    folder_path = os.path.join(ROOT_DIR, folder)

    paths = [
        os.path.join(folder_path, f)
        for f in os.listdir(folder_path)
        if fnmatch.fnmatch(f, PATTERN)
    ]
    paths.sort(key=lambda x: int(os.path.basename(x).split("_")[1].split(".")[0]))

    # Tính variance Laplacian
    valid_paths, scores = [], []
    for p in paths:
        v = var_laplacian_gray(p)
        if v is None:
            print(f"[CẢNH BÁO] Không đọc được: {p}")
            continue
        valid_paths.append(p)
        scores.append(v)

    thr = np.percentile(scores, PCT)
    keep_paths = [p for p, s in zip(valid_paths, scores) if s >= thr]

    results[folder] = keep_paths
    print(f"[{folder}] Tổng ảnh hợp lệ: {len(scores)} | Ngưỡng: {thr:.4f} | Giữ lại: {len(keep_paths)} ảnh")
# Out:
# [BMD] Tổng ảnh hợp lệ: 1300 | Ngưỡng: 0.9718 | Giữ lại: 1170 ảnh
# [DLDB22] Tổng ảnh hợp lệ: 399 | Ngưỡng: 1.6893 | Giữ lại: 359 ảnh
# [DLDB23] Tổng ảnh hợp lệ: 399 | Ngưỡng: 3.9327 | Giữ lại: 359 ảnh
# [DLDB24] Tổng ảnh hợp lệ: 399 | Ngưỡng: 2.8725 | Giữ lại: 359 ảnh
# [DLDB25] Tổng ảnh hợp lệ: 399 | Ngưỡng: 3.5019 | Giữ lại: 359 ảnh
# [DLDB26] Tổng ảnh hợp lệ: 399 | Ngưỡng: 0.9031 | Giữ lại: 359 ảnh
# [DuongThu_no_logo] Tổng ảnh hợp lệ: 1000 | Ngưỡng: 0.2472 | Giữ lại: 900 ảnh
# [NBDL] Tổng ảnh hợp lệ: 1200 | Ngưỡng: 1.4161 | Giữ lại: 1080 ảnh
# [STSH_no_logo] Tổng ảnh hợp lệ: 578 | Ngưỡng: 2.8742 | Giữ lại: 520 ảnh

# %% [markdown]
# # Loại bỏ ảnh quá tối/sáng

# %%
import shutil

# %%
DARK_THR = 25      # median brightness < DARK_THR => quá tối
BRIGHT_THR = 225   # median brightness > BRIGHT_THR => quá sáng
MOVE_REMOVED = True  # True -> di chuyển ảnh bị loại

# %%
def _safe_read_bgr(path):
    img = cv2.imread(path, cv2.IMREAD_COLOR)
    if img is None:
        try:
            arr = np.fromfile(path, dtype=np.uint8)
            img = cv2.imdecode(arr, cv2.IMREAD_COLOR)
        except Exception:
            return None
    return img

# %%
def brightness_median(path):
    img = _safe_read_bgr(path)
    if img is None:
        return None
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    return float(np.median(hsv[:, :, 2]))

# %%
cleaned_results = {}
removed_dark = {}

# %%
for folder, paths in results.items():
    keep, removed = [], []
    for p in paths:
        b = brightness_median(p)
        if b is None:
            print(f"[CẢNH BÁO] Không đọc được ảnh (brightness): {p}")
            continue
        if b < DARK_THR or b > BRIGHT_THR:
            removed.append(p)
        else:
            keep.append(p)
    """
    di chuyển ảnh removed vào 1 folder
    if MOVE_REMOVED and removed:
        for p in removed:
            parent = os.path.dirname(p) or "."
            dest_dir = os.path.join(parent, "removed_dark_bright")
            os.makedirs(dest_dir, exist_ok=True)
            try:
                shutil.move(p, os.path.join(dest_dir, os.path.basename(p)))
            except Exception as e:
                print(f"Không thể di chuyển {p}: {e}")
    Di chuyển ảnh giữ lại vào 1 folder
    if keep:
        for p in keep:
            parent = os.path.dirname(p) or "."
            dest_dir = os.path.join(parent, "keep_bright")
            os.makedirs(dest_dir, exist_ok=True)
            try:
                shutil.move(p, os.path.join(dest_dir, os.path.basename(p)))
            except Exception as e:
                print(f"Không thể di chuyển {p}: {e}")
    """

    cleaned_results[folder] = keep
    print(f"[{folder}] checked={len(paths)} | keep={len(keep)} | removed={len(removed)}")
# Out:
# [BMD] checked=1170 | keep=875 | removed=295
# [DLDB22] checked=359 | keep=308 | removed=51
# [DLDB23] checked=359 | keep=337 | removed=22
# [DLDB24] checked=359 | keep=331 | removed=28
# [DLDB25] checked=359 | keep=337 | removed=22
# [DLDB26] checked=359 | keep=270 | removed=89
# [DuongThu_no_logo] checked=900 | keep=673 | removed=227
# [NBDL] checked=1080 | keep=931 | removed=149
# [STSH_no_logo] checked=520 | keep=490 | removed=30

# %% [markdown]
# # Loại bỏ near-duplicates

# %%
from PIL import Image
import imagehash
import os

# %%
HAMMING_THR = 10  # ngưỡng Hamming

# %%
def phash_imagehash(path, hash_size=8):
    """Trả về imagehash.ImageHash hoặc None nếu không đọc được."""
    try:
        with Image.open(path) as img:
            return imagehash.phash(img, hash_size=hash_size)
    except Exception:
        return None

# %%
dedup_results = {}

# %%
for folder, paths in cleaned_results.items():
    if not paths:
        dedup_results[folder] = []
        print(f"[{folder}] Không có ảnh để dedup.")
        continue

    kept = []
    last_kept_hash = None
    last_kept_path = None

    for idx, p in enumerate(paths):
        h = phash_imagehash(p)

        if h is None:
            print(f"[CẢNH BÁO] Không đọc được để hash: {p} — giữ ảnh.")
            kept.append(p)
            last_kept_hash = None
            last_kept_path = None
            continue

        if last_kept_hash is None:
            # ảnh đầu tiên hoặc sau ảnh lỗi → giữ
            kept.append(p)
            last_kept_hash = h
            last_kept_path = p
            continue

        dist = last_kept_hash - h
        if dist <= HAMMING_THR:
            print(f"[{folder}] dup: {os.path.basename(last_kept_path)} <-> {os.path.basename(p)} | hamming={dist} -> loại {os.path.basename(p)}")
        else:
            kept.append(p)
            last_kept_hash = h
            last_kept_path = p

    dedup_results[folder] = kept
    print(f"[{folder}] from={len(paths)} kept={len(kept)} removed={len(paths)-len(kept)}")
# Out:
# [BMD] dup: frame_40.jpg <-> frame_41.jpg | hamming=6 -> loại frame_41.jpg
# [BMD] dup: frame_40.jpg <-> frame_42.jpg | hamming=10 -> loại frame_42.jpg
# [BMD] dup: frame_40.jpg <-> frame_43.jpg | hamming=10 -> loại frame_43.jpg
# [BMD] dup: frame_44.jpg <-> frame_45.jpg | hamming=4 -> loại frame_45.jpg
# [BMD] dup: frame_44.jpg <-> frame_46.jpg | hamming=8 -> loại frame_46.jpg
# [BMD] dup: frame_44.jpg <-> frame_47.jpg | hamming=8 -> loại frame_47.jpg
# [BMD] dup: frame_48.jpg <-> frame_49.jpg | hamming=8 -> loại frame_49.jpg
# [BMD] dup: frame_50.jpg <-> frame_51.jpg | hamming=10 -> loại frame_51.jpg
# [BMD] dup: frame_50.jpg <-> frame_52.jpg | hamming=10 -> loại frame_52.jpg
# [BMD] dup: frame_50.jpg <-> frame_53.jpg | hamming=10 -> loại frame_53.jpg
# [BMD] dup: frame_54.jpg <-> frame_55.jpg | hamming=6 -> loại frame_55.jpg
# [BMD] dup: frame_57.jpg <-> frame_58.jpg | hamming=2 -> loại frame_58.jpg
# [BMD] dup: frame_80.jpg <-> frame_81.jpg | hamming=6 -> loại frame_81.jpg
# [BMD] dup: frame_83.jpg <-> frame_84.jpg | hamming=10 -> loại frame_84.jpg
# [BMD] dup: frame_85.jpg <-> frame_86.jpg | hamming=6 -> loại frame_86.jpg
# [BMD] dup: frame_96.jpg <-> frame_97.jpg | hamming=10 -> loại frame_97.jpg
# [BMD] dup: frame_98.jpg <-> frame_99.jpg | hamming=2 -> loại frame_99.jpg
# [BMD] dup: frame_100.jpg <-> frame_101.jpg | hamming=4 -> loại frame_101.jpg
# [BMD] dup: frame_129.jpg <-> frame_130.jpg | hamming=6 -> loại frame_130.jpg
# [BMD] dup: frame_139.jpg <-> frame_140.jpg | hamming=8 -> loại frame_140.jpg
# [BMD] dup: frame_142.jpg <-> frame_143.jpg | hamming=8 -> loại frame_143.jpg
# [BMD] dup: frame_149.jpg <-> frame_150.jpg | hamming=10 -> loại frame_150.jpg
# [BMD] dup: frame_151.jpg <-> frame_152.jpg | hamming=8 -> loại frame_152.jpg
# [BMD] dup: frame_157.jpg <-> frame_158.jpg | hamming=10 -> loại frame_158.jpg
# [BMD] dup: frame_161.jpg <-> frame_162.jpg | hamming=10 -> loại frame_162.jpg
# [BMD] dup: frame_168.jpg <-> frame_169.jpg | hamming=8 -> loại frame_169.jpg
# [BMD] dup: frame_177.jpg <-> frame_178.jpg | hamming=2 -> loại frame_178.jpg
# [BMD] dup: frame_181.jpg <-> frame_182.jpg | hamming=8 -> loại frame_182.jpg
# [BMD] dup: frame_188.jpg <-> frame_189.jpg | hamming=6 -> loại frame_189.jpg
# [BMD] dup: frame_188.jpg <-> frame_190.jpg | hamming=8 -> loại frame_190.jpg
# [BMD] dup: frame_206.jpg <-> frame_207.jpg | hamming=4 -> loại frame_207.jpg
# [BMD] dup: frame_219.jpg <-> frame_220.jpg | hamming=10 -> loại frame_220.jpg
# [BMD] dup: frame_224.jpg <-> frame_225.jpg | hamming=2 -> loại frame_225.jpg
# [BMD] dup: frame_224.jpg <-> frame_226.jpg | hamming=6 -> loại frame_226.jpg
# [BMD] dup: frame_227.jpg <-> frame_228.jpg | hamming=6 -> loại frame_228.jpg
# [BMD] dup: frame_227.jpg <-> frame_229.jpg | hamming=10 -> loại frame_229.jpg
# [BMD] dup: frame_232.jpg <-> frame_233.jpg | hamming=6 -> loại frame_233.jpg
# [BMD] dup: frame_235.jpg <-> frame_236.jpg | hamming=4 -> loại frame_236.jpg
# [BMD] dup: frame_235.jpg <-> frame_237.jpg | hamming=4 -> loại frame_237.jpg
# [BMD] dup: frame_238.jpg <-> frame_239.jpg | hamming=8 -> loại frame_239.jpg
# [BMD] dup: frame_238.jpg <-> frame_240.jpg | hamming=8 -> loại frame_240.jpg
# [BMD] dup: frame_241.jpg <-> frame_242.jpg | hamming=8 -> loại frame_242.jpg
# [BMD] dup: frame_386.jpg <-> frame_387.jpg | hamming=8 -> loại frame_387.jpg
# [BMD] dup: frame_386.jpg <-> frame_388.jpg | hamming=10 -> loại frame_388.jpg
# [BMD] dup: frame_389.jpg <-> frame_390.jpg | hamming=6 -> loại frame_390.jpg
# [BMD] dup: frame_393.jpg <-> frame_394.jpg | hamming=4 -> loại frame_394.jpg
# [BMD] dup: frame_393.jpg <-> frame_395.jpg | hamming=8 -> loại frame_395.jpg
# [BMD] dup: frame_567.jpg <-> frame_568.jpg | hamming=10 -> loại frame_568.jpg
# [BMD] dup: frame_579.jpg <-> frame_580.jpg | hamming=10 -> loại frame_580.jpg
# [BMD] dup: frame_596.jpg <-> frame_597.jpg | hamming=6 -> loại frame_597.jpg
# [BMD] dup: frame_602.jpg <-> frame_603.jpg | hamming=10 -> loại frame_603.jpg
# [BMD] dup: frame_604.jpg <-> frame_605.jpg | hamming=8 -> loại frame_605.jpg
# [BMD] dup: frame_607.jpg <-> frame_608.jpg | hamming=8 -> loại frame_608.jpg
# [BMD] dup: frame_617.jpg <-> frame_618.jpg | hamming=8 -> loại frame_618.jpg
# [BMD] dup: frame_619.jpg <-> frame_620.jpg | hamming=10 -> loại frame_620.jpg
# [BMD] dup: frame_621.jpg <-> frame_622.jpg | hamming=8 -> loại frame_622.jpg
# [BMD] dup: frame_634.jpg <-> frame_635.jpg | hamming=8 -> loại frame_635.jpg
# [BMD] dup: frame_634.jpg <-> frame_636.jpg | hamming=10 -> loại frame_636.jpg
# [BMD] dup: frame_640.jpg <-> frame_641.jpg | hamming=10 -> loại frame_641.jpg
# [BMD] dup: frame_642.jpg <-> frame_643.jpg | hamming=4 -> loại frame_643.jpg
# [BMD] dup: frame_642.jpg <-> frame_644.jpg | hamming=10 -> loại frame_644.jpg
# [BMD] dup: frame_642.jpg <-> frame_645.jpg | hamming=10 -> loại frame_645.jpg
# [BMD] dup: frame_642.jpg <-> frame_646.jpg | hamming=10 -> loại frame_646.jpg
# [BMD] dup: frame_648.jpg <-> frame_649.jpg | hamming=6 -> loại frame_649.jpg
# [BMD] dup: frame_650.jpg <-> frame_651.jpg | hamming=10 -> loại frame_651.jpg
# [BMD] dup: frame_654.jpg <-> frame_655.jpg | hamming=6 -> loại frame_655.jpg
# [BMD] dup: frame_654.jpg <-> frame_656.jpg | hamming=10 -> loại frame_656.jpg
# [BMD] dup: frame_654.jpg <-> frame_657.jpg | hamming=6 -> loại frame_657.jpg
# [BMD] dup: frame_658.jpg <-> frame_659.jpg | hamming=8 -> loại frame_659.jpg
# [BMD] dup: frame_669.jpg <-> frame_670.jpg | hamming=6 -> loại frame_670.jpg
# [BMD] dup: frame_715.jpg <-> frame_716.jpg | hamming=8 -> loại frame_716.jpg
# [BMD] dup: frame_715.jpg <-> frame_717.jpg | hamming=10 -> loại frame_717.jpg
# [BMD] dup: frame_749.jpg <-> frame_750.jpg | hamming=4 -> loại frame_750.jpg
# [BMD] dup: frame_751.jpg <-> frame_752.jpg | hamming=2 -> loại frame_752.jpg
# [BMD] dup: frame_751.jpg <-> frame_753.jpg | hamming=4 -> loại frame_753.jpg
# [BMD] dup: frame_760.jpg <-> frame_761.jpg | hamming=4 -> loại frame_761.jpg
# [BMD] dup: frame_769.jpg <-> frame_770.jpg | hamming=2 -> loại frame_770.jpg
# [BMD] dup: frame_769.jpg <-> frame_771.jpg | hamming=4 -> loại frame_771.jpg
# [BMD] dup: frame_778.jpg <-> frame_779.jpg | hamming=8 -> loại frame_779.jpg
# [BMD] dup: frame_778.jpg <-> frame_780.jpg | hamming=6 -> loại frame_780.jpg
# [BMD] dup: frame_778.jpg <-> frame_781.jpg | hamming=8 -> loại frame_781.jpg
# [BMD] dup: frame_778.jpg <-> frame_782.jpg | hamming=8 -> loại frame_782.jpg
# [BMD] dup: frame_783.jpg <-> frame_784.jpg | hamming=0 -> loại frame_784.jpg
# [BMD] dup: frame_794.jpg <-> frame_795.jpg | hamming=6 -> loại frame_795.jpg
# [BMD] dup: frame_806.jpg <-> frame_807.jpg | hamming=2 -> loại frame_807.jpg
# [BMD] dup: frame_837.jpg <-> frame_838.jpg | hamming=2 -> loại frame_838.jpg
# [BMD] dup: frame_845.jpg <-> frame_846.jpg | hamming=6 -> loại frame_846.jpg
# [BMD] dup: frame_858.jpg <-> frame_859.jpg | hamming=2 -> loại frame_859.jpg
# [BMD] dup: frame_907.jpg <-> frame_908.jpg | hamming=10 -> loại frame_908.jpg
# [BMD] dup: frame_910.jpg <-> frame_911.jpg | hamming=6 -> loại frame_911.jpg
# [BMD] dup: frame_941.jpg <-> frame_942.jpg | hamming=10 -> loại frame_942.jpg
# [BMD] dup: frame_945.jpg <-> frame_946.jpg | hamming=8 -> loại frame_946.jpg
# [BMD] dup: frame_956.jpg <-> frame_957.jpg | hamming=8 -> loại frame_957.jpg
# [BMD] dup: frame_970.jpg <-> frame_971.jpg | hamming=4 -> loại frame_971.jpg
# [BMD] dup: frame_979.jpg <-> frame_980.jpg | hamming=0 -> loại frame_980.jpg
# [BMD] dup: frame_979.jpg <-> frame_981.jpg | hamming=6 -> loại frame_981.jpg
# [BMD] dup: frame_987.jpg <-> frame_988.jpg | hamming=4 -> loại frame_988.jpg
# [BMD] dup: frame_1021.jpg <-> frame_1022.jpg | hamming=10 -> loại frame_1022.jpg
# [BMD] dup: frame_1021.jpg <-> frame_1023.jpg | hamming=6 -> loại frame_1023.jpg
# [BMD] dup: frame_1024.jpg <-> frame_1025.jpg | hamming=2 -> loại frame_1025.jpg
# [BMD] dup: frame_1035.jpg <-> frame_1036.jpg | hamming=8 -> loại frame_1036.jpg
# [BMD] dup: frame_1041.jpg <-> frame_1042.jpg | hamming=8 -> loại frame_1042.jpg
# [BMD] dup: frame_1044.jpg <-> frame_1045.jpg | hamming=2 -> loại frame_1045.jpg
# [BMD] dup: frame_1087.jpg <-> frame_1088.jpg | hamming=8 -> loại frame_1088.jpg
# [BMD] dup: frame_1110.jpg <-> frame_1111.jpg | hamming=10 -> loại frame_1111.jpg
# [BMD] dup: frame_1110.jpg <-> frame_1112.jpg | hamming=10 -> loại frame_1112.jpg
# [BMD] dup: frame_1117.jpg <-> frame_1118.jpg | hamming=6 -> loại frame_1118.jpg
# [BMD] dup: frame_1117.jpg <-> frame_1119.jpg | hamming=10 -> loại frame_1119.jpg
# [BMD] dup: frame_1117.jpg <-> frame_1120.jpg | hamming=8 -> loại frame_1120.jpg
# [BMD] dup: frame_1117.jpg <-> frame_1121.jpg | hamming=10 -> loại frame_1121.jpg
# [BMD] dup: frame_1117.jpg <-> frame_1122.jpg | hamming=10 -> loại frame_1122.jpg
# [BMD] dup: frame_1123.jpg <-> frame_1124.jpg | hamming=2 -> loại frame_1124.jpg
# [BMD] dup: frame_1123.jpg <-> frame_1125.jpg | hamming=2 -> loại frame_1125.jpg
# [BMD] dup: frame_1123.jpg <-> frame_1126.jpg | hamming=2 -> loại frame_1126.jpg
# [BMD] dup: frame_1128.jpg <-> frame_1129.jpg | hamming=8 -> loại frame_1129.jpg
# [BMD] dup: frame_1131.jpg <-> frame_1132.jpg | hamming=4 -> loại frame_1132.jpg
# [BMD] dup: frame_1137.jpg <-> frame_1138.jpg | hamming=10 -> loại frame_1138.jpg
# [BMD] dup: frame_1141.jpg <-> frame_1142.jpg | hamming=10 -> loại frame_1142.jpg
# [BMD] dup: frame_1143.jpg <-> frame_1144.jpg | hamming=10 -> loại frame_1144.jpg
# [BMD] dup: frame_1143.jpg <-> frame_1145.jpg | hamming=10 -> loại frame_1145.jpg
# [BMD] dup: frame_1143.jpg <-> frame_1146.jpg | hamming=10 -> loại frame_1146.jpg
# [BMD] dup: frame_1147.jpg <-> frame_1148.jpg | hamming=10 -> loại frame_1148.jpg
# [BMD] dup: frame_1150.jpg <-> frame_1151.jpg | hamming=8 -> loại frame_1151.jpg
# [BMD] dup: frame_1156.jpg <-> frame_1157.jpg | hamming=8 -> loại frame_1157.jpg
# [BMD] dup: frame_1156.jpg <-> frame_1158.jpg | hamming=6 -> loại frame_1158.jpg
# [BMD] dup: frame_1156.jpg <-> frame_1159.jpg | hamming=8 -> loại frame_1159.jpg
# [BMD] dup: frame_1161.jpg <-> frame_1162.jpg | hamming=4 -> loại frame_1162.jpg
# [BMD] dup: frame_1161.jpg <-> frame_1163.jpg | hamming=8 -> loại frame_1163.jpg
# [BMD] dup: frame_1164.jpg <-> frame_1165.jpg | hamming=8 -> loại frame_1165.jpg
# [BMD] dup: frame_1164.jpg <-> frame_1166.jpg | hamming=10 -> loại frame_1166.jpg
# [BMD] dup: frame_1164.jpg <-> frame_1167.jpg | hamming=10 -> loại frame_1167.jpg
# [BMD] dup: frame_1168.jpg <-> frame_1169.jpg | hamming=0 -> loại frame_1169.jpg
# [BMD] dup: frame_1179.jpg <-> frame_1180.jpg | hamming=8 -> loại frame_1180.jpg
# [BMD] dup: frame_1183.jpg <-> frame_1184.jpg | hamming=8 -> loại frame_1184.jpg
# [BMD] dup: frame_1185.jpg <-> frame_1186.jpg | hamming=4 -> loại frame_1186.jpg
# [BMD] dup: frame_1188.jpg <-> frame_1189.jpg | hamming=8 -> loại frame_1189.jpg
# [BMD] dup: frame_1200.jpg <-> frame_1201.jpg | hamming=4 -> loại frame_1201.jpg
# [BMD] dup: frame_1224.jpg <-> frame_1225.jpg | hamming=4 -> loại frame_1225.jpg
# [BMD] dup: frame_1224.jpg <-> frame_1226.jpg | hamming=2 -> loại frame_1226.jpg
# [BMD] dup: frame_1224.jpg <-> frame_1227.jpg | hamming=6 -> loại frame_1227.jpg
# [BMD] dup: frame_1224.jpg <-> frame_1228.jpg | hamming=6 -> loại frame_1228.jpg
# [BMD] dup: frame_1230.jpg <-> frame_1231.jpg | hamming=6 -> loại frame_1231.jpg
# [BMD] dup: frame_1230.jpg <-> frame_1232.jpg | hamming=10 -> loại frame_1232.jpg
# [BMD] dup: frame_1233.jpg <-> frame_1234.jpg | hamming=10 -> loại frame_1234.jpg
# [BMD] dup: frame_1236.jpg <-> frame_1237.jpg | hamming=2 -> loại frame_1237.jpg
# [BMD] dup: frame_1236.jpg <-> frame_1238.jpg | hamming=2 -> loại frame_1238.jpg
# [BMD] dup: frame_1236.jpg <-> frame_1239.jpg | hamming=2 -> loại frame_1239.jpg
# [BMD] dup: frame_1236.jpg <-> frame_1240.jpg | hamming=2 -> loại frame_1240.jpg
# [BMD] from=875 kept=727 removed=148
# [DLDB22] dup: frame_34.jpg <-> frame_35.jpg | hamming=8 -> loại frame_35.jpg
# [DLDB22] dup: frame_37.jpg <-> frame_38.jpg | hamming=6 -> loại frame_38.jpg
# [DLDB22] dup: frame_37.jpg <-> frame_39.jpg | hamming=6 -> loại frame_39.jpg
# [DLDB22] dup: frame_40.jpg <-> frame_41.jpg | hamming=2 -> loại frame_41.jpg
# [DLDB22] dup: frame_46.jpg <-> frame_47.jpg | hamming=0 -> loại frame_47.jpg
# [DLDB22] dup: frame_72.jpg <-> frame_73.jpg | hamming=10 -> loại frame_73.jpg
# [DLDB22] dup: frame_95.jpg <-> frame_96.jpg | hamming=10 -> loại frame_96.jpg
# [DLDB22] dup: frame_189.jpg <-> frame_190.jpg | hamming=10 -> loại frame_190.jpg
# [DLDB22] dup: frame_189.jpg <-> frame_191.jpg | hamming=8 -> loại frame_191.jpg
# [DLDB22] dup: frame_212.jpg <-> frame_213.jpg | hamming=6 -> loại frame_213.jpg
# [DLDB22] dup: frame_212.jpg <-> frame_214.jpg | hamming=6 -> loại frame_214.jpg
# [DLDB22] dup: frame_212.jpg <-> frame_215.jpg | hamming=8 -> loại frame_215.jpg
# [DLDB22] dup: frame_221.jpg <-> frame_222.jpg | hamming=10 -> loại frame_222.jpg
# [DLDB22] dup: frame_223.jpg <-> frame_224.jpg | hamming=6 -> loại frame_224.jpg
# [DLDB22] dup: frame_231.jpg <-> frame_232.jpg | hamming=2 -> loại frame_232.jpg
# [DLDB22] dup: frame_234.jpg <-> frame_235.jpg | hamming=10 -> loại frame_235.jpg
# [DLDB22] dup: frame_234.jpg <-> frame_236.jpg | hamming=10 -> loại frame_236.jpg
# [DLDB22] dup: frame_239.jpg <-> frame_240.jpg | hamming=8 -> loại frame_240.jpg
# [DLDB22] dup: frame_239.jpg <-> frame_241.jpg | hamming=8 -> loại frame_241.jpg
# [DLDB22] dup: frame_244.jpg <-> frame_245.jpg | hamming=10 -> loại frame_245.jpg
# [DLDB22] dup: frame_251.jpg <-> frame_252.jpg | hamming=4 -> loại frame_252.jpg
# [DLDB22] dup: frame_260.jpg <-> frame_261.jpg | hamming=8 -> loại frame_261.jpg
# [DLDB22] dup: frame_260.jpg <-> frame_262.jpg | hamming=8 -> loại frame_262.jpg
# [DLDB22] dup: frame_284.jpg <-> frame_285.jpg | hamming=2 -> loại frame_285.jpg
# [DLDB22] dup: frame_292.jpg <-> frame_293.jpg | hamming=10 -> loại frame_293.jpg
# [DLDB22] dup: frame_296.jpg <-> frame_297.jpg | hamming=10 -> loại frame_297.jpg
# [DLDB22] dup: frame_308.jpg <-> frame_309.jpg | hamming=10 -> loại frame_309.jpg
# [DLDB22] dup: frame_328.jpg <-> frame_329.jpg | hamming=8 -> loại frame_329.jpg
# [DLDB22] dup: frame_358.jpg <-> frame_359.jpg | hamming=8 -> loại frame_359.jpg
# [DLDB22] dup: frame_373.jpg <-> frame_374.jpg | hamming=6 -> loại frame_374.jpg
# [DLDB22] dup: frame_381.jpg <-> frame_382.jpg | hamming=8 -> loại frame_382.jpg
# [DLDB22] from=308 kept=277 removed=31
# [DLDB23] dup: frame_52.jpg <-> frame_53.jpg | hamming=10 -> loại frame_53.jpg
# [DLDB23] dup: frame_52.jpg <-> frame_54.jpg | hamming=8 -> loại frame_54.jpg
# [DLDB23] dup: frame_68.jpg <-> frame_69.jpg | hamming=10 -> loại frame_69.jpg
# [DLDB23] dup: frame_94.jpg <-> frame_95.jpg | hamming=4 -> loại frame_95.jpg
# [DLDB23] dup: frame_96.jpg <-> frame_97.jpg | hamming=10 -> loại frame_97.jpg
# [DLDB23] dup: frame_112.jpg <-> frame_113.jpg | hamming=8 -> loại frame_113.jpg
# [DLDB23] dup: frame_119.jpg <-> frame_120.jpg | hamming=6 -> loại frame_120.jpg
# [DLDB23] dup: frame_119.jpg <-> frame_121.jpg | hamming=8 -> loại frame_121.jpg
# [DLDB23] dup: frame_119.jpg <-> frame_122.jpg | hamming=10 -> loại frame_122.jpg
# [DLDB23] dup: frame_119.jpg <-> frame_123.jpg | hamming=6 -> loại frame_123.jpg
# [DLDB23] dup: frame_167.jpg <-> frame_168.jpg | hamming=10 -> loại frame_168.jpg
# [DLDB23] dup: frame_173.jpg <-> frame_174.jpg | hamming=2 -> loại frame_174.jpg
# [DLDB23] dup: frame_181.jpg <-> frame_182.jpg | hamming=6 -> loại frame_182.jpg
# [DLDB23] dup: frame_205.jpg <-> frame_206.jpg | hamming=10 -> loại frame_206.jpg
# [DLDB23] dup: frame_209.jpg <-> frame_210.jpg | hamming=2 -> loại frame_210.jpg
# [DLDB23] dup: frame_209.jpg <-> frame_211.jpg | hamming=4 -> loại frame_211.jpg
# [DLDB23] dup: frame_212.jpg <-> frame_214.jpg | hamming=2 -> loại frame_214.jpg
# [DLDB23] dup: frame_217.jpg <-> frame_218.jpg | hamming=6 -> loại frame_218.jpg
# [DLDB23] dup: frame_217.jpg <-> frame_219.jpg | hamming=8 -> loại frame_219.jpg
# [DLDB23] dup: frame_224.jpg <-> frame_225.jpg | hamming=2 -> loại frame_225.jpg
# [DLDB23] dup: frame_226.jpg <-> frame_227.jpg | hamming=6 -> loại frame_227.jpg
# [DLDB23] dup: frame_234.jpg <-> frame_235.jpg | hamming=8 -> loại frame_235.jpg
# [DLDB23] dup: frame_250.jpg <-> frame_251.jpg | hamming=10 -> loại frame_251.jpg
# [DLDB23] dup: frame_250.jpg <-> frame_252.jpg | hamming=10 -> loại frame_252.jpg
# [DLDB23] dup: frame_260.jpg <-> frame_261.jpg | hamming=4 -> loại frame_261.jpg
# [DLDB23] dup: frame_291.jpg <-> frame_292.jpg | hamming=10 -> loại frame_292.jpg
# [DLDB23] dup: frame_314.jpg <-> frame_315.jpg | hamming=8 -> loại frame_315.jpg
# [DLDB23] dup: frame_314.jpg <-> frame_316.jpg | hamming=10 -> loại frame_316.jpg
# [DLDB23] dup: frame_318.jpg <-> frame_319.jpg | hamming=6 -> loại frame_319.jpg
# [DLDB23] dup: frame_323.jpg <-> frame_324.jpg | hamming=8 -> loại frame_324.jpg
# [DLDB23] dup: frame_332.jpg <-> frame_333.jpg | hamming=8 -> loại frame_333.jpg
# [DLDB23] dup: frame_332.jpg <-> frame_334.jpg | hamming=10 -> loại frame_334.jpg
# [DLDB23] dup: frame_332.jpg <-> frame_335.jpg | hamming=10 -> loại frame_335.jpg
# [DLDB23] dup: frame_337.jpg <-> frame_338.jpg | hamming=4 -> loại frame_338.jpg
# [DLDB23] dup: frame_337.jpg <-> frame_339.jpg | hamming=10 -> loại frame_339.jpg
# [DLDB23] dup: frame_346.jpg <-> frame_347.jpg | hamming=10 -> loại frame_347.jpg
# [DLDB23] dup: frame_351.jpg <-> frame_352.jpg | hamming=6 -> loại frame_352.jpg
# [DLDB23] dup: frame_376.jpg <-> frame_377.jpg | hamming=4 -> loại frame_377.jpg
# [DLDB23] dup: frame_376.jpg <-> frame_378.jpg | hamming=6 -> loại frame_378.jpg
# [DLDB23] from=337 kept=298 removed=39
# [DLDB24] dup: frame_31.jpg <-> frame_32.jpg | hamming=10 -> loại frame_32.jpg
# [DLDB24] dup: frame_31.jpg <-> frame_33.jpg | hamming=10 -> loại frame_33.jpg
# [DLDB24] dup: frame_39.jpg <-> frame_40.jpg | hamming=6 -> loại frame_40.jpg
# [DLDB24] dup: frame_43.jpg <-> frame_44.jpg | hamming=10 -> loại frame_44.jpg
# [DLDB24] dup: frame_69.jpg <-> frame_70.jpg | hamming=8 -> loại frame_70.jpg
# [DLDB24] dup: frame_78.jpg <-> frame_79.jpg | hamming=8 -> loại frame_79.jpg
# [DLDB24] dup: frame_109.jpg <-> frame_110.jpg | hamming=10 -> loại frame_110.jpg
# [DLDB24] dup: frame_118.jpg <-> frame_119.jpg | hamming=6 -> loại frame_119.jpg
# [DLDB24] dup: frame_121.jpg <-> frame_122.jpg | hamming=10 -> loại frame_122.jpg
# [DLDB24] dup: frame_123.jpg <-> frame_124.jpg | hamming=10 -> loại frame_124.jpg
# [DLDB24] dup: frame_126.jpg <-> frame_127.jpg | hamming=4 -> loại frame_127.jpg
# [DLDB24] dup: frame_140.jpg <-> frame_141.jpg | hamming=4 -> loại frame_141.jpg
# [DLDB24] dup: frame_140.jpg <-> frame_142.jpg | hamming=6 -> loại frame_142.jpg
# [DLDB24] dup: frame_144.jpg <-> frame_145.jpg | hamming=4 -> loại frame_145.jpg
# [DLDB24] dup: frame_150.jpg <-> frame_151.jpg | hamming=8 -> loại frame_151.jpg
# [DLDB24] dup: frame_158.jpg <-> frame_159.jpg | hamming=4 -> loại frame_159.jpg
# [DLDB24] dup: frame_158.jpg <-> frame_160.jpg | hamming=10 -> loại frame_160.jpg
# [DLDB24] dup: frame_162.jpg <-> frame_163.jpg | hamming=10 -> loại frame_163.jpg
# [DLDB24] dup: frame_169.jpg <-> frame_170.jpg | hamming=4 -> loại frame_170.jpg
# [DLDB24] dup: frame_182.jpg <-> frame_183.jpg | hamming=4 -> loại frame_183.jpg
# [DLDB24] dup: frame_182.jpg <-> frame_184.jpg | hamming=10 -> loại frame_184.jpg
# [DLDB24] dup: frame_185.jpg <-> frame_186.jpg | hamming=10 -> loại frame_186.jpg
# [DLDB24] dup: frame_192.jpg <-> frame_193.jpg | hamming=10 -> loại frame_193.jpg
# [DLDB24] dup: frame_194.jpg <-> frame_195.jpg | hamming=10 -> loại frame_195.jpg
# [DLDB24] dup: frame_206.jpg <-> frame_207.jpg | hamming=6 -> loại frame_207.jpg
# [DLDB24] dup: frame_217.jpg <-> frame_218.jpg | hamming=8 -> loại frame_218.jpg
# [DLDB24] dup: frame_221.jpg <-> frame_222.jpg | hamming=8 -> loại frame_222.jpg
# [DLDB24] dup: frame_221.jpg <-> frame_223.jpg | hamming=4 -> loại frame_223.jpg
# [DLDB24] dup: frame_248.jpg <-> frame_249.jpg | hamming=2 -> loại frame_249.jpg
# [DLDB24] dup: frame_248.jpg <-> frame_250.jpg | hamming=6 -> loại frame_250.jpg
# [DLDB24] dup: frame_258.jpg <-> frame_259.jpg | hamming=10 -> loại frame_259.jpg
# [DLDB24] dup: frame_263.jpg <-> frame_264.jpg | hamming=4 -> loại frame_264.jpg
# [DLDB24] dup: frame_267.jpg <-> frame_268.jpg | hamming=10 -> loại frame_268.jpg
# [DLDB24] dup: frame_267.jpg <-> frame_269.jpg | hamming=6 -> loại frame_269.jpg
# [DLDB24] dup: frame_273.jpg <-> frame_274.jpg | hamming=8 -> loại frame_274.jpg
# [DLDB24] dup: frame_273.jpg <-> frame_275.jpg | hamming=10 -> loại frame_275.jpg
# [DLDB24] dup: frame_306.jpg <-> frame_307.jpg | hamming=8 -> loại frame_307.jpg
# [DLDB24] dup: frame_306.jpg <-> frame_308.jpg | hamming=10 -> loại frame_308.jpg
# [DLDB24] dup: frame_309.jpg <-> frame_310.jpg | hamming=0 -> loại frame_310.jpg
# [DLDB24] dup: frame_320.jpg <-> frame_321.jpg | hamming=2 -> loại frame_321.jpg
# [DLDB24] dup: frame_320.jpg <-> frame_322.jpg | hamming=10 -> loại frame_322.jpg
# [DLDB24] dup: frame_320.jpg <-> frame_323.jpg | hamming=10 -> loại frame_323.jpg
# [DLDB24] dup: frame_327.jpg <-> frame_328.jpg | hamming=8 -> loại frame_328.jpg
# [DLDB24] dup: frame_329.jpg <-> frame_330.jpg | hamming=4 -> loại frame_330.jpg
# [DLDB24] dup: frame_329.jpg <-> frame_331.jpg | hamming=10 -> loại frame_331.jpg
# [DLDB24] dup: frame_338.jpg <-> frame_339.jpg | hamming=10 -> loại frame_339.jpg
# [DLDB24] dup: frame_340.jpg <-> frame_341.jpg | hamming=4 -> loại frame_341.jpg
# [DLDB24] dup: frame_340.jpg <-> frame_342.jpg | hamming=8 -> loại frame_342.jpg
# [DLDB24] dup: frame_340.jpg <-> frame_343.jpg | hamming=6 -> loại frame_343.jpg
# [DLDB24] dup: frame_340.jpg <-> frame_344.jpg | hamming=4 -> loại frame_344.jpg
# [DLDB24] dup: frame_345.jpg <-> frame_347.jpg | hamming=6 -> loại frame_347.jpg
# [DLDB24] dup: frame_345.jpg <-> frame_349.jpg | hamming=0 -> loại frame_349.jpg
# [DLDB24] dup: frame_352.jpg <-> frame_353.jpg | hamming=2 -> loại frame_353.jpg
# [DLDB24] dup: frame_362.jpg <-> frame_363.jpg | hamming=4 -> loại frame_363.jpg
# [DLDB24] dup: frame_364.jpg <-> frame_365.jpg | hamming=4 -> loại frame_365.jpg
# [DLDB24] dup: frame_364.jpg <-> frame_366.jpg | hamming=2 -> loại frame_366.jpg
# [DLDB24] dup: frame_368.jpg <-> frame_369.jpg | hamming=10 -> loại frame_369.jpg
# [DLDB24] dup: frame_368.jpg <-> frame_370.jpg | hamming=10 -> loại frame_370.jpg
# [DLDB24] dup: frame_373.jpg <-> frame_374.jpg | hamming=6 -> loại frame_374.jpg
# [DLDB24] dup: frame_376.jpg <-> frame_377.jpg | hamming=4 -> loại frame_377.jpg
# [DLDB24] dup: frame_378.jpg <-> frame_379.jpg | hamming=4 -> loại frame_379.jpg
# [DLDB24] dup: frame_380.jpg <-> frame_381.jpg | hamming=10 -> loại frame_381.jpg
# [DLDB24] from=331 kept=269 removed=62
# [DLDB25] dup: frame_32.jpg <-> frame_33.jpg | hamming=8 -> loại frame_33.jpg
# [DLDB25] dup: frame_37.jpg <-> frame_38.jpg | hamming=4 -> loại frame_38.jpg
# [DLDB25] dup: frame_39.jpg <-> frame_40.jpg | hamming=10 -> loại frame_40.jpg
# [DLDB25] dup: frame_48.jpg <-> frame_49.jpg | hamming=6 -> loại frame_49.jpg
# [DLDB25] dup: frame_48.jpg <-> frame_50.jpg | hamming=6 -> loại frame_50.jpg
# [DLDB25] dup: frame_59.jpg <-> frame_60.jpg | hamming=0 -> loại frame_60.jpg
# [DLDB25] dup: frame_61.jpg <-> frame_62.jpg | hamming=2 -> loại frame_62.jpg
# [DLDB25] dup: frame_64.jpg <-> frame_65.jpg | hamming=4 -> loại frame_65.jpg
# [DLDB25] dup: frame_64.jpg <-> frame_66.jpg | hamming=2 -> loại frame_66.jpg
# [DLDB25] dup: frame_72.jpg <-> frame_73.jpg | hamming=8 -> loại frame_73.jpg
# [DLDB25] dup: frame_72.jpg <-> frame_74.jpg | hamming=4 -> loại frame_74.jpg
# [DLDB25] dup: frame_72.jpg <-> frame_75.jpg | hamming=6 -> loại frame_75.jpg
# [DLDB25] dup: frame_83.jpg <-> frame_84.jpg | hamming=8 -> loại frame_84.jpg
# [DLDB25] dup: frame_96.jpg <-> frame_97.jpg | hamming=8 -> loại frame_97.jpg
# [DLDB25] dup: frame_99.jpg <-> frame_100.jpg | hamming=4 -> loại frame_100.jpg
# [DLDB25] dup: frame_108.jpg <-> frame_109.jpg | hamming=0 -> loại frame_109.jpg
# [DLDB25] dup: frame_108.jpg <-> frame_110.jpg | hamming=2 -> loại frame_110.jpg
# [DLDB25] dup: frame_112.jpg <-> frame_113.jpg | hamming=2 -> loại frame_113.jpg
# [DLDB25] dup: frame_112.jpg <-> frame_114.jpg | hamming=2 -> loại frame_114.jpg
# [DLDB25] dup: frame_115.jpg <-> frame_116.jpg | hamming=2 -> loại frame_116.jpg
# [DLDB25] dup: frame_117.jpg <-> frame_118.jpg | hamming=6 -> loại frame_118.jpg
# [DLDB25] dup: frame_133.jpg <-> frame_134.jpg | hamming=8 -> loại frame_134.jpg
# [DLDB25] dup: frame_133.jpg <-> frame_135.jpg | hamming=8 -> loại frame_135.jpg
# [DLDB25] dup: frame_133.jpg <-> frame_136.jpg | hamming=8 -> loại frame_136.jpg
# [DLDB25] dup: frame_133.jpg <-> frame_137.jpg | hamming=8 -> loại frame_137.jpg
# [DLDB25] dup: frame_133.jpg <-> frame_138.jpg | hamming=2 -> loại frame_138.jpg
# [DLDB25] dup: frame_133.jpg <-> frame_139.jpg | hamming=2 -> loại frame_139.jpg
# [DLDB25] dup: frame_133.jpg <-> frame_140.jpg | hamming=2 -> loại frame_140.jpg
# [DLDB25] dup: frame_133.jpg <-> frame_141.jpg | hamming=2 -> loại frame_141.jpg
# [DLDB25] dup: frame_167.jpg <-> frame_168.jpg | hamming=6 -> loại frame_168.jpg
# [DLDB25] dup: frame_173.jpg <-> frame_174.jpg | hamming=2 -> loại frame_174.jpg
# [DLDB25] dup: frame_176.jpg <-> frame_177.jpg | hamming=2 -> loại frame_177.jpg
# [DLDB25] dup: frame_176.jpg <-> frame_178.jpg | hamming=2 -> loại frame_178.jpg
# [DLDB25] dup: frame_184.jpg <-> frame_185.jpg | hamming=4 -> loại frame_185.jpg
# [DLDB25] dup: frame_184.jpg <-> frame_186.jpg | hamming=4 -> loại frame_186.jpg
# [DLDB25] dup: frame_189.jpg <-> frame_190.jpg | hamming=6 -> loại frame_190.jpg
# [DLDB25] dup: frame_192.jpg <-> frame_193.jpg | hamming=2 -> loại frame_193.jpg
# [DLDB25] dup: frame_192.jpg <-> frame_194.jpg | hamming=4 -> loại frame_194.jpg
# [DLDB25] dup: frame_192.jpg <-> frame_195.jpg | hamming=6 -> loại frame_195.jpg
# [DLDB25] dup: frame_197.jpg <-> frame_198.jpg | hamming=4 -> loại frame_198.jpg
# [DLDB25] dup: frame_200.jpg <-> frame_201.jpg | hamming=4 -> loại frame_201.jpg
# [DLDB25] dup: frame_205.jpg <-> frame_206.jpg | hamming=6 -> loại frame_206.jpg
# [DLDB25] dup: frame_207.jpg <-> frame_208.jpg | hamming=8 -> loại frame_208.jpg
# [DLDB25] dup: frame_212.jpg <-> frame_213.jpg | hamming=2 -> loại frame_213.jpg
# [DLDB25] dup: frame_212.jpg <-> frame_214.jpg | hamming=4 -> loại frame_214.jpg
# [DLDB25] dup: frame_212.jpg <-> frame_215.jpg | hamming=2 -> loại frame_215.jpg
# [DLDB25] dup: frame_212.jpg <-> frame_216.jpg | hamming=4 -> loại frame_216.jpg
# [DLDB25] dup: frame_217.jpg <-> frame_218.jpg | hamming=6 -> loại frame_218.jpg
# [DLDB25] dup: frame_219.jpg <-> frame_220.jpg | hamming=8 -> loại frame_220.jpg
# [DLDB25] dup: frame_219.jpg <-> frame_221.jpg | hamming=6 -> loại frame_221.jpg
# [DLDB25] dup: frame_222.jpg <-> frame_223.jpg | hamming=0 -> loại frame_223.jpg
# [DLDB25] dup: frame_224.jpg <-> frame_225.jpg | hamming=8 -> loại frame_225.jpg
# [DLDB25] dup: frame_227.jpg <-> frame_228.jpg | hamming=6 -> loại frame_228.jpg
# [DLDB25] dup: frame_227.jpg <-> frame_229.jpg | hamming=4 -> loại frame_229.jpg
# [DLDB25] dup: frame_230.jpg <-> frame_231.jpg | hamming=8 -> loại frame_231.jpg
# [DLDB25] dup: frame_230.jpg <-> frame_232.jpg | hamming=10 -> loại frame_232.jpg
# [DLDB25] dup: frame_233.jpg <-> frame_234.jpg | hamming=2 -> loại frame_234.jpg
# [DLDB25] dup: frame_233.jpg <-> frame_235.jpg | hamming=4 -> loại frame_235.jpg
# [DLDB25] dup: frame_239.jpg <-> frame_240.jpg | hamming=2 -> loại frame_240.jpg
# [DLDB25] dup: frame_239.jpg <-> frame_241.jpg | hamming=2 -> loại frame_241.jpg
# [DLDB25] dup: frame_242.jpg <-> frame_243.jpg | hamming=6 -> loại frame_243.jpg
# [DLDB25] dup: frame_244.jpg <-> frame_245.jpg | hamming=2 -> loại frame_245.jpg
# [DLDB25] dup: frame_255.jpg <-> frame_256.jpg | hamming=8 -> loại frame_256.jpg
# [DLDB25] dup: frame_255.jpg <-> frame_257.jpg | hamming=10 -> loại frame_257.jpg
# [DLDB25] dup: frame_260.jpg <-> frame_261.jpg | hamming=10 -> loại frame_261.jpg
# [DLDB25] dup: frame_273.jpg <-> frame_274.jpg | hamming=2 -> loại frame_274.jpg
# [DLDB25] dup: frame_273.jpg <-> frame_275.jpg | hamming=0 -> loại frame_275.jpg
# [DLDB25] dup: frame_273.jpg <-> frame_276.jpg | hamming=0 -> loại frame_276.jpg
# [DLDB25] dup: frame_278.jpg <-> frame_279.jpg | hamming=6 -> loại frame_279.jpg
# [DLDB25] dup: frame_281.jpg <-> frame_282.jpg | hamming=2 -> loại frame_282.jpg
# [DLDB25] dup: frame_286.jpg <-> frame_287.jpg | hamming=2 -> loại frame_287.jpg
# [DLDB25] dup: frame_289.jpg <-> frame_290.jpg | hamming=2 -> loại frame_290.jpg
# [DLDB25] dup: frame_289.jpg <-> frame_291.jpg | hamming=8 -> loại frame_291.jpg
# [DLDB25] dup: frame_301.jpg <-> frame_302.jpg | hamming=6 -> loại frame_302.jpg
# [DLDB25] dup: frame_303.jpg <-> frame_304.jpg | hamming=10 -> loại frame_304.jpg
# [DLDB25] dup: frame_311.jpg <-> frame_312.jpg | hamming=4 -> loại frame_312.jpg
# [DLDB25] dup: frame_315.jpg <-> frame_316.jpg | hamming=6 -> loại frame_316.jpg
# [DLDB25] dup: frame_330.jpg <-> frame_331.jpg | hamming=6 -> loại frame_331.jpg
# [DLDB25] dup: frame_334.jpg <-> frame_335.jpg | hamming=6 -> loại frame_335.jpg
# [DLDB25] dup: frame_340.jpg <-> frame_341.jpg | hamming=10 -> loại frame_341.jpg
# [DLDB25] dup: frame_365.jpg <-> frame_366.jpg | hamming=4 -> loại frame_366.jpg
# [DLDB25] from=337 kept=256 removed=81
# [DLDB26] dup: frame_46.jpg <-> frame_47.jpg | hamming=6 -> loại frame_47.jpg
# [DLDB26] dup: frame_53.jpg <-> frame_54.jpg | hamming=2 -> loại frame_54.jpg
# [DLDB26] dup: frame_59.jpg <-> frame_60.jpg | hamming=4 -> loại frame_60.jpg
# [DLDB26] dup: frame_93.jpg <-> frame_94.jpg | hamming=8 -> loại frame_94.jpg
# [DLDB26] dup: frame_234.jpg <-> frame_235.jpg | hamming=10 -> loại frame_235.jpg
# [DLDB26] dup: frame_238.jpg <-> frame_239.jpg | hamming=6 -> loại frame_239.jpg
# [DLDB26] dup: frame_255.jpg <-> frame_256.jpg | hamming=8 -> loại frame_256.jpg
# [DLDB26] dup: frame_314.jpg <-> frame_315.jpg | hamming=6 -> loại frame_315.jpg
# [DLDB26] dup: frame_323.jpg <-> frame_324.jpg | hamming=8 -> loại frame_324.jpg
# [DLDB26] dup: frame_383.jpg <-> frame_384.jpg | hamming=6 -> loại frame_384.jpg
# [DLDB26] from=270 kept=260 removed=10
# [DuongThu_no_logo] dup: frame_6.jpg <-> frame_7.jpg | hamming=10 -> loại frame_7.jpg
# [DuongThu_no_logo] dup: frame_19.jpg <-> frame_20.jpg | hamming=10 -> loại frame_20.jpg
# [DuongThu_no_logo] dup: frame_32.jpg <-> frame_33.jpg | hamming=6 -> loại frame_33.jpg
# [DuongThu_no_logo] dup: frame_65.jpg <-> frame_66.jpg | hamming=6 -> loại frame_66.jpg
# [DuongThu_no_logo] dup: frame_96.jpg <-> frame_97.jpg | hamming=8 -> loại frame_97.jpg
# [DuongThu_no_logo] dup: frame_142.jpg <-> frame_143.jpg | hamming=4 -> loại frame_143.jpg
# [DuongThu_no_logo] dup: frame_153.jpg <-> frame_154.jpg | hamming=10 -> loại frame_154.jpg
# [DuongThu_no_logo] dup: frame_153.jpg <-> frame_155.jpg | hamming=10 -> loại frame_155.jpg
# [DuongThu_no_logo] dup: frame_169.jpg <-> frame_170.jpg | hamming=8 -> loại frame_170.jpg
# [DuongThu_no_logo] dup: frame_186.jpg <-> frame_187.jpg | hamming=10 -> loại frame_187.jpg
# [DuongThu_no_logo] dup: frame_191.jpg <-> frame_192.jpg | hamming=8 -> loại frame_192.jpg
# [DuongThu_no_logo] dup: frame_197.jpg <-> frame_198.jpg | hamming=2 -> loại frame_198.jpg
# [DuongThu_no_logo] dup: frame_219.jpg <-> frame_220.jpg | hamming=8 -> loại frame_220.jpg
# [DuongThu_no_logo] dup: frame_221.jpg <-> frame_222.jpg | hamming=4 -> loại frame_222.jpg
# [DuongThu_no_logo] dup: frame_221.jpg <-> frame_223.jpg | hamming=6 -> loại frame_223.jpg
# [DuongThu_no_logo] dup: frame_224.jpg <-> frame_225.jpg | hamming=4 -> loại frame_225.jpg
# [DuongThu_no_logo] dup: frame_224.jpg <-> frame_226.jpg | hamming=2 -> loại frame_226.jpg
# [DuongThu_no_logo] dup: frame_272.jpg <-> frame_273.jpg | hamming=6 -> loại frame_273.jpg
# [DuongThu_no_logo] dup: frame_272.jpg <-> frame_274.jpg | hamming=6 -> loại frame_274.jpg
# [DuongThu_no_logo] dup: frame_294.jpg <-> frame_295.jpg | hamming=10 -> loại frame_295.jpg
# [DuongThu_no_logo] dup: frame_305.jpg <-> frame_306.jpg | hamming=8 -> loại frame_306.jpg
# [DuongThu_no_logo] dup: frame_307.jpg <-> frame_308.jpg | hamming=6 -> loại frame_308.jpg
# [DuongThu_no_logo] dup: frame_315.jpg <-> frame_316.jpg | hamming=10 -> loại frame_316.jpg
# [DuongThu_no_logo] dup: frame_321.jpg <-> frame_322.jpg | hamming=8 -> loại frame_322.jpg
# [DuongThu_no_logo] dup: frame_340.jpg <-> frame_341.jpg | hamming=6 -> loại frame_341.jpg
# [DuongThu_no_logo] dup: frame_342.jpg <-> frame_343.jpg | hamming=10 -> loại frame_343.jpg
# [DuongThu_no_logo] dup: frame_344.jpg <-> frame_345.jpg | hamming=6 -> loại frame_345.jpg
# [DuongThu_no_logo] dup: frame_344.jpg <-> frame_346.jpg | hamming=10 -> loại frame_346.jpg
# [DuongThu_no_logo] dup: frame_344.jpg <-> frame_347.jpg | hamming=6 -> loại frame_347.jpg
# [DuongThu_no_logo] dup: frame_356.jpg <-> frame_357.jpg | hamming=10 -> loại frame_357.jpg
# [DuongThu_no_logo] dup: frame_358.jpg <-> frame_359.jpg | hamming=8 -> loại frame_359.jpg
# [DuongThu_no_logo] dup: frame_361.jpg <-> frame_362.jpg | hamming=6 -> loại frame_362.jpg
# [DuongThu_no_logo] dup: frame_363.jpg <-> frame_364.jpg | hamming=10 -> loại frame_364.jpg
# [DuongThu_no_logo] dup: frame_370.jpg <-> frame_371.jpg | hamming=4 -> loại frame_371.jpg
# [DuongThu_no_logo] dup: frame_398.jpg <-> frame_399.jpg | hamming=6 -> loại frame_399.jpg
# [DuongThu_no_logo] dup: frame_408.jpg <-> frame_409.jpg | hamming=10 -> loại frame_409.jpg
# [DuongThu_no_logo] dup: frame_421.jpg <-> frame_422.jpg | hamming=8 -> loại frame_422.jpg
# [DuongThu_no_logo] dup: frame_423.jpg <-> frame_424.jpg | hamming=2 -> loại frame_424.jpg
# [DuongThu_no_logo] dup: frame_423.jpg <-> frame_425.jpg | hamming=6 -> loại frame_425.jpg
# [DuongThu_no_logo] dup: frame_457.jpg <-> frame_458.jpg | hamming=4 -> loại frame_458.jpg
# [DuongThu_no_logo] dup: frame_460.jpg <-> frame_462.jpg | hamming=8 -> loại frame_462.jpg
# [DuongThu_no_logo] dup: frame_460.jpg <-> frame_463.jpg | hamming=6 -> loại frame_463.jpg
# [DuongThu_no_logo] dup: frame_508.jpg <-> frame_509.jpg | hamming=4 -> loại frame_509.jpg
# [DuongThu_no_logo] dup: frame_522.jpg <-> frame_523.jpg | hamming=0 -> loại frame_523.jpg
# [DuongThu_no_logo] dup: frame_525.jpg <-> frame_526.jpg | hamming=4 -> loại frame_526.jpg
# [DuongThu_no_logo] dup: frame_546.jpg <-> frame_547.jpg | hamming=0 -> loại frame_547.jpg
# [DuongThu_no_logo] dup: frame_569.jpg <-> frame_570.jpg | hamming=4 -> loại frame_570.jpg
# [DuongThu_no_logo] dup: frame_571.jpg <-> frame_572.jpg | hamming=8 -> loại frame_572.jpg
# [DuongThu_no_logo] dup: frame_588.jpg <-> frame_589.jpg | hamming=8 -> loại frame_589.jpg
# [DuongThu_no_logo] dup: frame_611.jpg <-> frame_612.jpg | hamming=10 -> loại frame_612.jpg
# [DuongThu_no_logo] dup: frame_638.jpg <-> frame_639.jpg | hamming=4 -> loại frame_639.jpg
# [DuongThu_no_logo] dup: frame_676.jpg <-> frame_677.jpg | hamming=4 -> loại frame_677.jpg
# [DuongThu_no_logo] dup: frame_676.jpg <-> frame_678.jpg | hamming=4 -> loại frame_678.jpg
# [DuongThu_no_logo] dup: frame_699.jpg <-> frame_700.jpg | hamming=4 -> loại frame_700.jpg
# [DuongThu_no_logo] dup: frame_699.jpg <-> frame_701.jpg | hamming=4 -> loại frame_701.jpg
# [DuongThu_no_logo] dup: frame_699.jpg <-> frame_702.jpg | hamming=4 -> loại frame_702.jpg
# [DuongThu_no_logo] dup: frame_889.jpg <-> frame_890.jpg | hamming=10 -> loại frame_890.jpg
# [DuongThu_no_logo] dup: frame_893.jpg <-> frame_894.jpg | hamming=2 -> loại frame_894.jpg
# [DuongThu_no_logo] dup: frame_893.jpg <-> frame_895.jpg | hamming=6 -> loại frame_895.jpg
# [DuongThu_no_logo] dup: frame_893.jpg <-> frame_896.jpg | hamming=8 -> loại frame_896.jpg
# [DuongThu_no_logo] dup: frame_906.jpg <-> frame_907.jpg | hamming=10 -> loại frame_907.jpg
# [DuongThu_no_logo] dup: frame_982.jpg <-> frame_983.jpg | hamming=2 -> loại frame_983.jpg
# [DuongThu_no_logo] dup: frame_982.jpg <-> frame_984.jpg | hamming=2 -> loại frame_984.jpg
# [DuongThu_no_logo] dup: frame_987.jpg <-> frame_988.jpg | hamming=4 -> loại frame_988.jpg
# [DuongThu_no_logo] dup: frame_993.jpg <-> frame_994.jpg | hamming=8 -> loại frame_994.jpg
# [DuongThu_no_logo] from=673 kept=608 removed=65
# [NBDL] dup: frame_8.jpg <-> frame_9.jpg | hamming=10 -> loại frame_9.jpg
# [NBDL] dup: frame_19.jpg <-> frame_20.jpg | hamming=0 -> loại frame_20.jpg
# [NBDL] dup: frame_38.jpg <-> frame_39.jpg | hamming=4 -> loại frame_39.jpg
# [NBDL] dup: frame_46.jpg <-> frame_47.jpg | hamming=6 -> loại frame_47.jpg
# [NBDL] dup: frame_59.jpg <-> frame_60.jpg | hamming=10 -> loại frame_60.jpg
# [NBDL] dup: frame_100.jpg <-> frame_101.jpg | hamming=0 -> loại frame_101.jpg
# [NBDL] dup: frame_125.jpg <-> frame_126.jpg | hamming=6 -> loại frame_126.jpg
# [NBDL] dup: frame_141.jpg <-> frame_142.jpg | hamming=10 -> loại frame_142.jpg
# [NBDL] dup: frame_143.jpg <-> frame_144.jpg | hamming=10 -> loại frame_144.jpg
# [NBDL] dup: frame_157.jpg <-> frame_158.jpg | hamming=4 -> loại frame_158.jpg
# [NBDL] dup: frame_161.jpg <-> frame_162.jpg | hamming=8 -> loại frame_162.jpg
# [NBDL] dup: frame_163.jpg <-> frame_164.jpg | hamming=4 -> loại frame_164.jpg
# [NBDL] dup: frame_189.jpg <-> frame_190.jpg | hamming=6 -> loại frame_190.jpg
# [NBDL] dup: frame_199.jpg <-> frame_200.jpg | hamming=8 -> loại frame_200.jpg
# [NBDL] dup: frame_199.jpg <-> frame_201.jpg | hamming=10 -> loại frame_201.jpg
# [NBDL] dup: frame_216.jpg <-> frame_217.jpg | hamming=10 -> loại frame_217.jpg
# [NBDL] dup: frame_221.jpg <-> frame_222.jpg | hamming=6 -> loại frame_222.jpg
# [NBDL] dup: frame_226.jpg <-> frame_227.jpg | hamming=6 -> loại frame_227.jpg
# [NBDL] dup: frame_234.jpg <-> frame_235.jpg | hamming=8 -> loại frame_235.jpg
# [NBDL] dup: frame_278.jpg <-> frame_279.jpg | hamming=2 -> loại frame_279.jpg
# [NBDL] dup: frame_291.jpg <-> frame_292.jpg | hamming=0 -> loại frame_292.jpg
# [NBDL] dup: frame_291.jpg <-> frame_293.jpg | hamming=6 -> loại frame_293.jpg
# [NBDL] dup: frame_291.jpg <-> frame_294.jpg | hamming=8 -> loại frame_294.jpg
# [NBDL] dup: frame_291.jpg <-> frame_295.jpg | hamming=6 -> loại frame_295.jpg
# [NBDL] dup: frame_299.jpg <-> frame_300.jpg | hamming=2 -> loại frame_300.jpg
# [NBDL] dup: frame_305.jpg <-> frame_306.jpg | hamming=6 -> loại frame_306.jpg
# [NBDL] dup: frame_344.jpg <-> frame_345.jpg | hamming=4 -> loại frame_345.jpg
# [NBDL] dup: frame_349.jpg <-> frame_350.jpg | hamming=10 -> loại frame_350.jpg
# [NBDL] dup: frame_407.jpg <-> frame_408.jpg | hamming=4 -> loại frame_408.jpg
# [NBDL] dup: frame_461.jpg <-> frame_462.jpg | hamming=10 -> loại frame_462.jpg
# [NBDL] dup: frame_463.jpg <-> frame_464.jpg | hamming=10 -> loại frame_464.jpg
# [NBDL] dup: frame_473.jpg <-> frame_474.jpg | hamming=6 -> loại frame_474.jpg
# [NBDL] dup: frame_506.jpg <-> frame_507.jpg | hamming=6 -> loại frame_507.jpg
# [NBDL] dup: frame_508.jpg <-> frame_509.jpg | hamming=2 -> loại frame_509.jpg
# [NBDL] dup: frame_537.jpg <-> frame_538.jpg | hamming=10 -> loại frame_538.jpg
# [NBDL] dup: frame_545.jpg <-> frame_546.jpg | hamming=8 -> loại frame_546.jpg
# [NBDL] dup: frame_549.jpg <-> frame_550.jpg | hamming=10 -> loại frame_550.jpg
# [NBDL] dup: frame_549.jpg <-> frame_551.jpg | hamming=10 -> loại frame_551.jpg
# [NBDL] dup: frame_599.jpg <-> frame_600.jpg | hamming=6 -> loại frame_600.jpg
# [NBDL] dup: frame_652.jpg <-> frame_653.jpg | hamming=8 -> loại frame_653.jpg
# [NBDL] dup: frame_671.jpg <-> frame_672.jpg | hamming=4 -> loại frame_672.jpg
# [NBDL] dup: frame_673.jpg <-> frame_674.jpg | hamming=6 -> loại frame_674.jpg
# [NBDL] dup: frame_673.jpg <-> frame_675.jpg | hamming=8 -> loại frame_675.jpg
# [NBDL] dup: frame_673.jpg <-> frame_676.jpg | hamming=4 -> loại frame_676.jpg
# [NBDL] dup: frame_693.jpg <-> frame_694.jpg | hamming=8 -> loại frame_694.jpg
# [NBDL] dup: frame_719.jpg <-> frame_720.jpg | hamming=2 -> loại frame_720.jpg
# [NBDL] dup: frame_719.jpg <-> frame_721.jpg | hamming=8 -> loại frame_721.jpg
# [NBDL] dup: frame_719.jpg <-> frame_722.jpg | hamming=8 -> loại frame_722.jpg
# [NBDL] dup: frame_727.jpg <-> frame_728.jpg | hamming=8 -> loại frame_728.jpg
# [NBDL] dup: frame_744.jpg <-> frame_745.jpg | hamming=2 -> loại frame_745.jpg
# [NBDL] dup: frame_766.jpg <-> frame_767.jpg | hamming=6 -> loại frame_767.jpg
# [NBDL] dup: frame_780.jpg <-> frame_781.jpg | hamming=6 -> loại frame_781.jpg
# [NBDL] dup: frame_981.jpg <-> frame_982.jpg | hamming=10 -> loại frame_982.jpg
# [NBDL] dup: frame_983.jpg <-> frame_984.jpg | hamming=4 -> loại frame_984.jpg
# [NBDL] dup: frame_985.jpg <-> frame_986.jpg | hamming=10 -> loại frame_986.jpg
# [NBDL] dup: frame_987.jpg <-> frame_988.jpg | hamming=2 -> loại frame_988.jpg
# [NBDL] dup: frame_987.jpg <-> frame_989.jpg | hamming=2 -> loại frame_989.jpg
# [NBDL] dup: frame_1007.jpg <-> frame_1008.jpg | hamming=10 -> loại frame_1008.jpg
# [NBDL] dup: frame_1016.jpg <-> frame_1017.jpg | hamming=2 -> loại frame_1017.jpg
# [NBDL] dup: frame_1036.jpg <-> frame_1037.jpg | hamming=2 -> loại frame_1037.jpg
# [NBDL] dup: frame_1050.jpg <-> frame_1051.jpg | hamming=0 -> loại frame_1051.jpg
# [NBDL] dup: frame_1052.jpg <-> frame_1053.jpg | hamming=10 -> loại frame_1053.jpg
# [NBDL] dup: frame_1061.jpg <-> frame_1062.jpg | hamming=4 -> loại frame_1062.jpg
# [NBDL] dup: frame_1063.jpg <-> frame_1064.jpg | hamming=6 -> loại frame_1064.jpg
# [NBDL] dup: frame_1063.jpg <-> frame_1065.jpg | hamming=6 -> loại frame_1065.jpg
# [NBDL] dup: frame_1066.jpg <-> frame_1067.jpg | hamming=2 -> loại frame_1067.jpg
# [NBDL] dup: frame_1068.jpg <-> frame_1069.jpg | hamming=4 -> loại frame_1069.jpg
# [NBDL] dup: frame_1075.jpg <-> frame_1076.jpg | hamming=6 -> loại frame_1076.jpg
# [NBDL] dup: frame_1085.jpg <-> frame_1086.jpg | hamming=6 -> loại frame_1086.jpg
# [NBDL] dup: frame_1085.jpg <-> frame_1087.jpg | hamming=6 -> loại frame_1087.jpg
# [NBDL] dup: frame_1085.jpg <-> frame_1088.jpg | hamming=8 -> loại frame_1088.jpg
# [NBDL] dup: frame_1093.jpg <-> frame_1094.jpg | hamming=8 -> loại frame_1094.jpg
# [NBDL] dup: frame_1095.jpg <-> frame_1096.jpg | hamming=4 -> loại frame_1096.jpg
# [NBDL] dup: frame_1107.jpg <-> frame_1108.jpg | hamming=2 -> loại frame_1108.jpg
# [NBDL] dup: frame_1124.jpg <-> frame_1125.jpg | hamming=6 -> loại frame_1125.jpg
# [NBDL] dup: frame_1126.jpg <-> frame_1127.jpg | hamming=10 -> loại frame_1127.jpg
# [NBDL] from=931 kept=855 removed=76
# [STSH_no_logo] dup: frame_4.jpg <-> frame_5.jpg | hamming=4 -> loại frame_5.jpg
# [STSH_no_logo] dup: frame_7.jpg <-> frame_8.jpg | hamming=10 -> loại frame_8.jpg
# [STSH_no_logo] dup: frame_30.jpg <-> frame_31.jpg | hamming=10 -> loại frame_31.jpg
# [STSH_no_logo] dup: frame_35.jpg <-> frame_36.jpg | hamming=6 -> loại frame_36.jpg
# [STSH_no_logo] dup: frame_41.jpg <-> frame_42.jpg | hamming=2 -> loại frame_42.jpg
# [STSH_no_logo] dup: frame_63.jpg <-> frame_64.jpg | hamming=8 -> loại frame_64.jpg
# [STSH_no_logo] dup: frame_63.jpg <-> frame_65.jpg | hamming=10 -> loại frame_65.jpg
# [STSH_no_logo] dup: frame_96.jpg <-> frame_97.jpg | hamming=10 -> loại frame_97.jpg
# [STSH_no_logo] dup: frame_114.jpg <-> frame_115.jpg | hamming=8 -> loại frame_115.jpg
# [STSH_no_logo] dup: frame_124.jpg <-> frame_125.jpg | hamming=10 -> loại frame_125.jpg
# [STSH_no_logo] dup: frame_130.jpg <-> frame_131.jpg | hamming=4 -> loại frame_131.jpg
# [STSH_no_logo] dup: frame_144.jpg <-> frame_145.jpg | hamming=4 -> loại frame_145.jpg
# [STSH_no_logo] dup: frame_163.jpg <-> frame_164.jpg | hamming=6 -> loại frame_164.jpg
# [STSH_no_logo] dup: frame_163.jpg <-> frame_165.jpg | hamming=8 -> loại frame_165.jpg
# [STSH_no_logo] dup: frame_163.jpg <-> frame_166.jpg | hamming=4 -> loại frame_166.jpg
# [STSH_no_logo] dup: frame_167.jpg <-> frame_168.jpg | hamming=10 -> loại frame_168.jpg
# [STSH_no_logo] dup: frame_190.jpg <-> frame_191.jpg | hamming=8 -> loại frame_191.jpg
# [STSH_no_logo] dup: frame_192.jpg <-> frame_193.jpg | hamming=0 -> loại frame_193.jpg
# [STSH_no_logo] dup: frame_199.jpg <-> frame_200.jpg | hamming=6 -> loại frame_200.jpg
# [STSH_no_logo] dup: frame_199.jpg <-> frame_201.jpg | hamming=10 -> loại frame_201.jpg
# [STSH_no_logo] dup: frame_262.jpg <-> frame_263.jpg | hamming=6 -> loại frame_263.jpg
# [STSH_no_logo] dup: frame_265.jpg <-> frame_266.jpg | hamming=6 -> loại frame_266.jpg
# [STSH_no_logo] dup: frame_280.jpg <-> frame_281.jpg | hamming=8 -> loại frame_281.jpg
# [STSH_no_logo] dup: frame_284.jpg <-> frame_285.jpg | hamming=4 -> loại frame_285.jpg
# [STSH_no_logo] dup: frame_284.jpg <-> frame_286.jpg | hamming=6 -> loại frame_286.jpg
# [STSH_no_logo] dup: frame_296.jpg <-> frame_297.jpg | hamming=4 -> loại frame_297.jpg
# [STSH_no_logo] dup: frame_299.jpg <-> frame_300.jpg | hamming=10 -> loại frame_300.jpg
# [STSH_no_logo] dup: frame_299.jpg <-> frame_301.jpg | hamming=6 -> loại frame_301.jpg
# [STSH_no_logo] dup: frame_299.jpg <-> frame_302.jpg | hamming=8 -> loại frame_302.jpg
# [STSH_no_logo] dup: frame_320.jpg <-> frame_321.jpg | hamming=10 -> loại frame_321.jpg
# [STSH_no_logo] dup: frame_329.jpg <-> frame_330.jpg | hamming=6 -> loại frame_330.jpg
# [STSH_no_logo] dup: frame_329.jpg <-> frame_331.jpg | hamming=6 -> loại frame_331.jpg
# [STSH_no_logo] dup: frame_329.jpg <-> frame_332.jpg | hamming=4 -> loại frame_332.jpg
# [STSH_no_logo] dup: frame_359.jpg <-> frame_360.jpg | hamming=10 -> loại frame_360.jpg
# [STSH_no_logo] dup: frame_359.jpg <-> frame_361.jpg | hamming=10 -> loại frame_361.jpg
# [STSH_no_logo] dup: frame_364.jpg <-> frame_365.jpg | hamming=6 -> loại frame_365.jpg
# [STSH_no_logo] dup: frame_364.jpg <-> frame_366.jpg | hamming=4 -> loại frame_366.jpg
# [STSH_no_logo] dup: frame_396.jpg <-> frame_397.jpg | hamming=10 -> loại frame_397.jpg
# [STSH_no_logo] dup: frame_413.jpg <-> frame_414.jpg | hamming=4 -> loại frame_414.jpg
# [STSH_no_logo] dup: frame_413.jpg <-> frame_415.jpg | hamming=10 -> loại frame_415.jpg
# [STSH_no_logo] dup: frame_413.jpg <-> frame_416.jpg | hamming=10 -> loại frame_416.jpg
# [STSH_no_logo] dup: frame_420.jpg <-> frame_421.jpg | hamming=6 -> loại frame_421.jpg
# [STSH_no_logo] dup: frame_455.jpg <-> frame_456.jpg | hamming=10 -> loại frame_456.jpg
# [STSH_no_logo] dup: frame_462.jpg <-> frame_463.jpg | hamming=8 -> loại frame_463.jpg
# [STSH_no_logo] dup: frame_490.jpg <-> frame_491.jpg | hamming=6 -> loại frame_491.jpg
# [STSH_no_logo] dup: frame_500.jpg <-> frame_501.jpg | hamming=10 -> loại frame_501.jpg
# [STSH_no_logo] dup: frame_522.jpg <-> frame_523.jpg | hamming=6 -> loại frame_523.jpg
# [STSH_no_logo] dup: frame_533.jpg <-> frame_534.jpg | hamming=4 -> loại frame_534.jpg
# [STSH_no_logo] dup: frame_533.jpg <-> frame_535.jpg | hamming=10 -> loại frame_535.jpg
# [STSH_no_logo] dup: frame_533.jpg <-> frame_536.jpg | hamming=6 -> loại frame_536.jpg
# [STSH_no_logo] dup: frame_543.jpg <-> frame_544.jpg | hamming=6 -> loại frame_544.jpg
# [STSH_no_logo] dup: frame_543.jpg <-> frame_545.jpg | hamming=8 -> loại frame_545.jpg
# [STSH_no_logo] dup: frame_548.jpg <-> frame_549.jpg | hamming=6 -> loại frame_549.jpg
# [STSH_no_logo] dup: frame_548.jpg <-> frame_550.jpg | hamming=6 -> loại frame_550.jpg
# [STSH_no_logo] dup: frame_573.jpg <-> frame_574.jpg | hamming=8 -> loại frame_574.jpg
# [STSH_no_logo] dup: frame_577.jpg <-> frame_578.jpg | hamming=4 -> loại frame_578.jpg
# [STSH_no_logo] from=490 kept=434 removed=56

# %% [markdown]
# # Chuẩn bị tập train thành 1 folder chứa ảnh màu và 1 folder chứa ảnh trắng đen

# %%
# Thư mục gốc (chứa Color_image và Grayscale_image)
BASE = "cleaned"
COLOR_DIR = os.path.join(BASE, "Color_image")
GRAY_DIR = os.path.join(BASE, "Grayscale_image")

# %%
# Tạo các folder đích
os.makedirs(COLOR_DIR, exist_ok=True)
os.makedirs(GRAY_DIR, exist_ok=True)

# %%
# dedup_results phải tồn tại: dict {folder_name: [list đường dẫn ảnh, ...], ...}
for folder, paths in dedup_results.items():
    color_subdir = os.path.join(COLOR_DIR, folder)
    gray_subdir = os.path.join(GRAY_DIR, folder)
    os.makedirs(color_subdir, exist_ok=True)
    os.makedirs(gray_subdir, exist_ok=True)

    for img_path in paths:
        if not os.path.isfile(img_path):
            print(f"[CẢNH BÁO] Không tìm thấy file: {img_path}")
            continue

        # copy ảnh màu nguyên bản
        try:
            shutil.copy2(img_path, os.path.join(color_subdir, os.path.basename(img_path)))
        except Exception as e:
            print(f"[LỖI] Không copy {img_path}: {e}")
            continue

        # đọc và chuyển sang grayscale rồi lưu
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)
        if img is None:
            print(f"[CẢNH BÁO] Không đọc được ảnh để chuyển grayscale: {img_path}")
            continue
        gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        dest_gray = os.path.join(gray_subdir, os.path.basename(img_path))
        if not cv2.imwrite(dest_gray, gray_img):
            print(f"[LỖI] Không lưu được grayscale: {dest_gray}")

print("✅ Hoàn tất. Color_image và Grayscale_image nằm trong thư mục 'cleaned'.")
# Out:
# ✅ Hoàn tất. Color_image và Grayscale_image nằm trong thư mục 'cleaned'.
